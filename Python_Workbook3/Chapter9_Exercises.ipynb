# %% [markdown]
# EXERCISE 1

# %%
# Create a dictionary with the following keys and values showing a partial list of Real GDP growth in Annual percent change from IMF
# (Source: http://www.imf.org/external/datamapper/NGDP_RPCH@WEO/OEMDC/ADVEC/WEOWORLD)

# China 6.5
# Japan 0.7
# Philippines 6.7
# United States 2.3

gdp_growth = {
    'China': 6.5,
    'Japan': 0.7,
    'Philippines': 6.7,
    'United States': 2.3
}

# %% [markdown]
# EXERCISE 2

# %%
# Display all the keys and values from the dictionary you created above

print("Keys:", gdp_growth.keys())
print("Values:", gdp_growth.values())
# Out:
# Keys: dict_keys(['China', 'Japan', 'Philippines', 'United States'])
# Values: dict_values([6.5, 0.7, 6.7, 2.3])

# %% [markdown]
# EXERCISE 3

# %%
# Write a program that asks the user to enter a line of text and then counts the number of each word that appeared in the line of text.
# Use the string function split() to make a list of words from a given string e.g.:

# word_list = line.split()
# will return a list of words from the string line and store it in the variable word_list.

line = input("Enter a line of the text: ")
word_list = line.split()
count = {}
for word in word_list :
    if word in count:
        count[word] += 1
    else:
        count[word] = 1
for key in count :
    print(key, "=" , count[key])
# Out:
# Enter a line of the text: h
# h = 1
