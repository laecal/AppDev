# %% [markdown]
# Chapter 1

# %% [markdown]
# Exercise 1

# %%
Print('Hello world!')

# %%
print('Hello world!')
#this is the corrected code from the above error. The print function should start in small letter "p" as it is built in function of Python.

# %%
print'Hello world!')

# %%
#the error in the above code is the missing left brace in print function. Below is the corrected code.
print('Hello Worl!d')

# %%
print('Hello world!)

# %%
#there is a missing right single quotation mark in the statement. The hello world statement is a string so it should have either a single or double quotation mark.
#below is the corrected code
print('Hello world!')

# %%
print('Hello world!'')

# %%
#there is a double right single quotation in the statement. In order for this to work, delete the other single quotation.
print('Hello world!')

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print(x)

# %%
#the output of the code above is 44 as 43 + 1 = 44 stored in variable x.

# %% [markdown]
# Exercise 3

# %%
x = 43
x = X + 1
print(x)

# %%
#There is a variable naming error in line 2. X and x is different variable name as Python is case sensitive.
#the below code is the corrected one.
x = 43
x = x + 1
print(x)
