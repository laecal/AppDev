# %% [markdown]
# EXERCISE 1

# %%
# Investigate on the difference between is and == given the following variables.

# a = 2
# b = 2.0
# c = a

c is a #is keyword is used to check if two objects are the same object.
a == b #the == operator compares the value of equality of two objects.
      #It returns true if both the operands are equal. In this case, it returns false.

# %% [markdown]
# CHALLENGE 1

# %%
# Write a program which repeatedly reads numbers until the user enters "done".
# Once "done" is entered, print out the total, count, and average of the numbers.
# If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.

# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16 3 5.333333333333333

total = 0
count = 0

while True:
    entered_num = input("Enter a number (or 'done' to stop): ")

    if entered_num == 'done':
        break
    try:
        digit = float(entered_num)
        total += digit
        count += 1
    except:
        print("Invalid input")
        continue

if count > 0:
    average = total / count
else:
    average = 0

print("Total:", total)
print("Count:", count)
print("Average:", average)
# Out:
# Enter a number (or 'done' to stop): 4
# Enter a number (or 'done' to stop): 5
# Enter a number (or 'done' to stop): bad data
# Invalid input
# Enter a number (or 'done' to stop): 7
# Enter a number (or 'done' to stop): done
# Total: 16.0
# Count: 3
# Average: 5.333333333333333

# %% [markdown]
# CHALLENGE 2

# %%
# Write another program that prompts for a list of numbers as
# above and at the end prints out both the maximum and minimum of the numbers instead of the average.

max = 0
min = 0
index = 1

while True:

    entered_input = input("Enter a number (or 'done' to stop): ")
    if entered_input == 'done':
        break
    try:
        number = int(entered_input)
        if index == 1:
          max = number
          min = number

        if number > max:
          max = number

        if number < min:
          min = number

        index = 2

    except :
        print("Invalid input. Please enter a number or 'done'.")

if index == 2:
  print("Maximum:", max)
  print("Minimum:", min)
else:
  print("No number is entered.")
# Out:
# Enter a number (or 'done' to stop): 5
# Enter a number (or 'done' to stop): 7
# Enter a number (or 'done' to stop): 4
# Enter a number (or 'done' to stop): 2
# Enter a number (or 'done' to stop): done
# Maximum: 7
# Minimum: 2
